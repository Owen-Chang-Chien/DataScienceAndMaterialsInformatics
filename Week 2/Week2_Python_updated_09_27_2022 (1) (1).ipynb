# %% [markdown]
# # Data Science And Materials Informatics
#
# ## Hands-on Week 2: Introduction to Numpy, Scipy & Pandas

# %% [markdown]
# ### Python Data Science Ecosystem
#
# The usefulness of Python for data science stems primarily from the large and active ecosystem of third-party packages.
# Some of the most important ones are:
#
# #### [``numpy``](http://numpy.org/): Numerical Python
#
# This library provides the ``ndarray`` for efficient storage and manipulation of dense data arrays in Python.
#
# #### [``scipy``](http://scipy.org/): Scientific Python
#
# This library contains a wide range of functionality for accomplishing common scientific tasks, such as optimization/minimization, numerical integration, interpolation, and much more.
#
# #### [``pandas``](http://pandas.pydata.org/): Panel Data
#
# This library provides the ``DataFrame`` for efficient storage and manipulation of labeled/columnar data in Python.
#
# #### [``matplotlib``](http://matplotlib.org): MATLAB-style Plotting via Gnuplot
#
# This library provides capabilities for a flexible range of publication-quality data visualizations in Python.
#
# The PyData world is certainly much larger than these four packages, and is growing every day.

# %% [markdown]
# Reference: [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html)

# %% [markdown]
# *The following is not meant to be a self-contained introduction to this introduction to ``numpy`` and ``pandas``. Please use a search engine and online resources generously. Almost all issues you will encounter will have a solution online!*

# %% [markdown]
# ## Numpy
# ### 1. Data types in Python

# %% [markdown]
# Unlike the C language, the data types of each variable in Python are dynamically inferred. This means that we can assign any kind of data to any variable:

# %%
a = 1
a = "one"
a
# Out:
# 'one'

# %% [markdown]
# *Notice that Jupyter notebooks will typically display only the last variable, unless something is already programmed to output something. One could always use ``print()``, etc to see variable values. For instance, what is the difference in output between the above and: ``a = 1; print(a); a = "one"; a``? Of course, one could suppress output entirely using a ``;``, for instance, by changing the last line in the cell above from ``a`` to ``a;``. As clear in these examples, the ``;`` also allows for one to write multiple statements in the same line.*

# %% [markdown]
# The standard mutable multi-element container in Python is the list. We can create a list of items as follows:

# %%
L = [4, 2.0, "10", True] 
[type(item) for item in L] # Creating lists this way is called "list comprehension". 
                           # This is considerably easier than the equivalent: [type(4), type(2.0), type("10"), type(True)]
# Out:
# [int, float, str, bool]

# %% [markdown]
# To allow these flexible types, each item in the list must contain its own type info, reference count, and other information. In the special case that all variables are of the same type, much of this information is redundant: it can be much more efficient to store data in a fixed-type array (NumPy-style).

# %% [markdown]
# Importing different libraries usually is the first cell of a jupyter notebook.

# %%
# The os module provides dozens of functions for interacting with the operating system.
# The re module provides regular expression tools for advanced string processing.
# Other different libraries if needed...
import os
import re
import numpy
numpy.__version__
# Out:
# '1.21.4'

# %% [markdown]
# By convention, most people in the SciPy/PyData world will import Numpy under a shortened name using the ``import ... as ...`` pattern:

# %%
import numpy as np

# %% [markdown]
# Remember NumPy is constrained to arrays that all contain the same type. If types do not match, NumPy will upcast if possible:

# %%
np.array([1, 2, 3, 3.14])
# Out:
# array([1.  , 2.  , 3.  , 3.14])

# %%
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %% [markdown]
# NumPy arrays can explicitly be multi-dimensional:

# %%
x = np.array([range(i, i + 4) for i in [1, 3, 6]])  # range(i, j), j>i, (i, i+1, i+2.......j-1)
x
# Out:
# array([[1, 2, 3, 4],
#        [3, 4, 5, 6],
#        [6, 7, 8, 9]])

# %% [markdown]
# range(a, b): a is the start number, b is the stop number (not included).

# %% [markdown]
# The ``dtypes`` attribute gives the data types of each column:

# %%
x.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ``ndim``: the number of dimensions
#
# ``shape``: the size of each dimension
#
# ``size``: the total size of the array

# %%
print("ndim: ", x.ndim)  # 2D dimension
print("shape: ", x.shape)  # 3 rows and 4 columns
print("size: ", x.size)  # 12 numbers in the array
# Out:
# ndim:  2
# shape:  (3, 4)
# size:  12

# %% [markdown]
# Multi-dimensional slices:

# %%
x[:2, :3] # More examples: https://www.w3schools.com/python/numpy/numpy_array_slicing.asp # 2 rows and 3 columns
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])

# %% [markdown]
# Reshaping of Arrays:

# %%
x_re = x.reshape((4, 3))  # x_re = x.reshape(4, 3)
x_re
# Out:
# array([[1, 2, 3],
#        [4, 3, 4],
#        [5, 6, 6],
#        [7, 8, 9]])

# %% [markdown]
# #### Exercise 1:  Reshape x to 2 columns, 6 rows:

# %%
x_re = x.reshape((6, 2))
x_re
# Out:
# array([[1, 2],
#        [3, 4],
#        [3, 4],
#        [5, 6],
#        [6, 7],
#        [8, 9]])

# %% [markdown]
# ### 2. Computation on Numpy Arrays

# %% [markdown]
# Summing the values in an array:

# %%
y = np.random.random(1000000)  # from 0 to 1000000
print(y)
sum(y)
# Out:
# [0.4412636  0.82400103 0.85493003 ... 0.02163569 0.65371035 0.64286865]
# 500600.4578394146

# %% [markdown]
# The first ``random`` in ``np.random.random()`` is a class. The second ``random`` in ``np.random.random()`` is a method.
#
# Essentially, a class is grouping functions (as methods) and data (as properties) into a logical unit.

# %% [markdown]
# The syntax is quite similar to that of NumPy's sum function, and the result is the same. But, the time taken may vary, as we will see using ``timeit`` in the following cell.

# %%
np.sum(y)
# Out:
# 500600.4578394332

# %% [markdown]
# On JupyterLab %timeit might take long to show.

# %%
# %timeit sum(y)
# %timeit np.sum(y)
# Out:
# 85.8 ms ± 4.79 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 387 µs ± 12.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### 3. Structured data

# %%
element = ['C', 'O', 'S']
atomic_number = [6, 8, 16]
atomic_mass = [12.001, 15.999, 32.06]

# %%
data = np.zeros(3, dtype={'names':('element', 'atomic_number', 'atomic_mass'),
                          'formats':('U10', 'i4', 'f16')}) # U10 is string type, i4 is integers, f16 is floats
       # U10, i4 and f16 are data types. More examples: https://jakevdp.github.io/PythonDataScienceHandbook/02.09-structured-data-numpy.html
data.dtype
# Out:
# dtype([('element', '<U10'), ('atomic_number', '<i4'), ('atomic_mass', '<f16')])

# %% [markdown]
# Assign values to columns by their name, using square-bracket indexing:

# %%
data['element'] = element
data['atomic_number'] = atomic_number
data['atomic_mass'] = atomic_mass
print(data)
# Out:
# [('C',  6, 12.001) ('O',  8, 15.999) ('S', 16, 32.06 )]

# %% [markdown]
# Another way to specify structured data types:

# %%
ty = np.dtype([('element', 'U10'), ('atomic_number', 'i4'), ('atomic_mass', 'f16')])
d = np.zeros(3, dtype=ty)
data['element'] = element
data['atomic_number'] = atomic_number
data['atomic_mass'] = atomic_mass
print(data)
# Out:
# [('C',  6, 12.001) ('O',  8, 15.999) ('S', 16, 32.06 )]

# %% [markdown]
# ## Pandas
# ### 1. Loading data with Pandas

# %%
import pandas as pd
pd.__path__
# Out:
# ['/opt/conda/lib/python3.9/site-packages/pandas']

# %% [markdown]
# To display the package's built-in documentation, we can use this:

# %%
pd?
# Out:
# Type:        module
# String form: <module 'pandas' from '/opt/conda/lib/python3.9/site-packages/pandas/__init__.py'>
# File:        /opt/conda/lib/python3.9/site-packages/pandas/__init__.py
# Docstring:
# pandas - a powerful data analysis and manipulation library for Python
# =====================================================================
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
#     to a set of labels, or the user can simply ignore the labels and let
#     `Series`, `DataFrame`, etc. automatically align the data for you in
#     computations.
#   - Powerful, flexible group by functionality to perform split-apply-combine
#     operations on data sets, for both aggregating and transforming data.
#   - Make it easy to convert ragged, differently-indexed data in other Python
#     and NumPy data structures into DataFrame objects.
#   - Intelligent label-based slicing, fancy indexing, and subsetting of large
#     data sets.
#   - Intuitive merging and joining data sets.
#   - Flexible reshaping and pivoting of data sets.
#   - Hierarchical labeling of axes (possible to have multiple labels per tick).
#   - Robust IO tools for loading data from flat files (CSV and delimited),
#     Excel files, databases, and saving/loading data from the ultrafast HDF5
#     format.
#   - Time series-specific functionality: date range generation and frequency
#     conversion, moving window statistics, date shifting and lagging.

# %% [markdown]
# Now we can use the ``read_csv`` command to read the comma-separated-value data (here it is a periodic table):

# %%
data = pd.read_csv("https://gist.githubusercontent.com/GoodmanSciences/c2dd862cd38f21b0ad36b8f96b4bf1ee/raw/1d92663004489a5b6926e944c1b3d9ec5c40900e/Periodic%2520Table%2520of%2520Elements.csv")
data
# Out:
#      AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# 0               1     Hydrogen      H       1.007                 0
# 1               2       Helium     He       4.002                 2
# 2               3      Lithium     Li       6.941                 4
# 3               4    Beryllium     Be       9.012                 5
# 4               5        Boron      B      10.811                 6
# ..            ...          ...    ...         ...               ...
# 113           114    Flerovium     Fl     289.000               175
# 114           115    Moscovium     Mc     288.000               173
# 115           116  Livermorium     Lv     292.000               176
# 116           117   Tennessine     Ts     295.000               178
# 117           118    Oganesson     Og     294.000               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 0                  1                  1       1    1.0         gas  ...
# 1                  2                  2       1   18.0         gas  ...
# 2                  3                  3       2    1.0       solid  ...
# 3                  4                  4       2    2.0       solid  ...
# 4                  5                  5       2   13.0       solid  ...
# ..               ...                ...     ...    ...         ...  ...
# 113              114                114       7   14.0  artificial  ...
# 114              115                115       7   15.0  artificial  ...
# 115              116                116       7   16.0  artificial  ...
# 116              117                117       7   17.0  artificial  ...
# 117              118                118       7   18.0  artificial  ...
#
#     FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0           13.5984  0.000090       14.175        20.28              3.0
# 1           24.5874  0.000179          NaN         4.22              5.0
# 2            5.3917  0.534000      453.850      1615.00              5.0
# 3            9.3227  1.850000     1560.150      2742.00              6.0
# 4            8.2980  2.340000     2573.150      4200.00              6.0
# ..              ...       ...          ...          ...              ...
# 113             NaN       NaN          NaN          NaN              NaN
# 114             NaN       NaN          NaN          NaN              NaN
# 115             NaN       NaN          NaN          NaN              NaN
# 116             NaN       NaN          NaN          NaN              NaN
# 117             NaN       NaN          NaN          NaN              NaN
#
#      Discoverer    Year  SpecificHeat  NumberofShells  NumberofValence
# 0     Cavendish  1766.0        14.304               1              1.0
# 1       Janssen  1868.0         5.193               1              NaN
# 2     Arfvedson  1817.0         3.582               2              1.0
# 3    Vaulquelin  1798.0         1.825               2              2.0
# 4    Gay-Lussac  1808.0         1.026               2              3.0
# ..          ...     ...           ...             ...              ...
# 113         NaN  1999.0           NaN               7              4.0
# 114         NaN  2010.0           NaN               7              5.0
# 115         NaN  2000.0           NaN               7              6.0
# 116         NaN  2010.0           NaN               7              7.0
# 117         NaN  2006.0           NaN               7              8.0
#
# [118 rows x 28 columns]

# %% [markdown]
# #### Exercise 2: Try to read the data from a downloaded file rather than from an online resource. Please use the file (Janus_band_structure.csv) provided in the same folder as this notebook.

# %%
data2 = pd.read_csv('Janus_band_structure.csv')
data2
# Out:
#             k   energy  band_localization  special_points
# 0         NaN      NaN                NaN             NaN
# 1      0.0000 -61.6075           0.999951          0.0000
# 2      0.0082 -61.6075           0.999951          0.5774
# 3      0.0165 -61.6075           0.999951          0.9107
# 4      0.0247 -61.6075           0.999951          1.5774
# ...       ...      ...                ...             ...
# 15434  1.5440   2.3895           0.995841             NaN
# 15435  1.5524   2.4025           0.994669             NaN
# 15436  1.5607   2.4135           0.996949             NaN
# 15437  1.5690   2.4205           0.998770             NaN
# 15438  1.5774   2.4225           0.997991             NaN
#
# [15439 rows x 4 columns]

# %% [markdown]
# ### 2. Viewing Pandas Dataframes

# %% [markdown]
# The ``head()`` and ``tail()`` methods show us the first and last rows of the data:

# %%
data.head()  # we can put a number in head(), for example, head(10)
             # head() only shows the top 5 rows
# Out:
#    AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# 0             1   Hydrogen      H       1.007                 0
# 1             2     Helium     He       4.002                 2
# 2             3    Lithium     Li       6.941                 4
# 3             4  Beryllium     Be       9.012                 5
# 4             5      Boron      B      10.811                 6
#
#    NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# 0                1                  1       1    1.0    gas  ...
# 1                2                  2       1   18.0    gas  ...
# 2                3                  3       2    1.0  solid  ...
# 3                4                  4       2    2.0  solid  ...
# 4                5                  5       2   13.0  solid  ...
#
#   FirstIonization   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 0         13.5984  0.000090       14.175        20.28              3.0
# 1         24.5874  0.000179          NaN         4.22              5.0
# 2          5.3917  0.534000      453.850      1615.00              5.0
# 3          9.3227  1.850000     1560.150      2742.00              6.0
# 4          8.2980  2.340000     2573.150      4200.00              6.0
#
#    Discoverer    Year  SpecificHeat  NumberofShells  NumberofValence
# 0   Cavendish  1766.0        14.304               1              1.0
# 1     Janssen  1868.0         5.193               1              NaN
# 2   Arfvedson  1817.0         3.582               2              1.0
# 3  Vaulquelin  1798.0         1.825               2              2.0
# 4  Gay-Lussac  1808.0         1.026               2              3.0
#
# [5 rows x 28 columns]

# %%
data.tail(10)
# Out:
#      AtomicNumber        Element Symbol  AtomicMass  NumberofNeutrons  \
# 108           109     Meitnerium     Mt       268.0               159
# 109           110  Darmstadtium     Ds        271.0               161
# 110           111   Roentgenium     Rg        272.0               161
# 111           112   Copernicium     Cn        285.0               173
# 112           113       Nihonium     Nh       284.0               171
# 113           114      Flerovium     Fl       289.0               175
# 114           115      Moscovium     Mc       288.0               173
# 115           116    Livermorium     Lv       292.0               176
# 116           117     Tennessine     Ts       295.0               178
# 117           118      Oganesson     Og       294.0               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 108              109                109       7    9.0  artificial  ...
# 109              110                110       7   10.0  artificial  ...
# 110              111                111       7   11.0  artificial  ...
# 111              112                112       7   12.0  artificial  ...
# 112              113                113       7   13.0  artificial  ...
# 113              114                114       7   14.0  artificial  ...
# 114              115                115       7   15.0  artificial  ...
# 115              116                116       7   16.0  artificial  ...
# 116              117                117       7   17.0  artificial  ...
# 117              118                118       7   18.0  artificial  ...
#
#     FirstIonization Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# 108             NaN    35.0          NaN          NaN              NaN
# 109             NaN     NaN          NaN          NaN              NaN
# 110             NaN     NaN          NaN          NaN              NaN
# 111             NaN     NaN          NaN          NaN              NaN
# 112             NaN     NaN          NaN          NaN              NaN
# 113             NaN     NaN          NaN          NaN              NaN
# 114             NaN     NaN          NaN          NaN              NaN
# 115             NaN     NaN          NaN          NaN              NaN
# 116             NaN     NaN          NaN          NaN              NaN
# 117             NaN     NaN          NaN          NaN              NaN
#
#                        Discoverer    Year  SpecificHeat  NumberofShells  \
# 108  GSI, Darmstadt, West Germany  1982.0           NaN               7
# 109                           NaN  1994.0           NaN               7
# 110                           NaN  1994.0           NaN               7
# 111                           NaN  1996.0           NaN               7
# 112                           NaN  2004.0           NaN               7
# 113                           NaN  1999.0           NaN               7
# 114                           NaN  2010.0           NaN               7
# 115                           NaN  2000.0           NaN               7
# 116                           NaN  2010.0           NaN               7
# 117                           NaN  2006.0           NaN               7
#
#      NumberofValence
# 108              NaN
# 109              NaN
# 110              NaN
# 111              NaN
# 112              3.0
# 113              4.0
# 114              5.0
# 115              6.0
# 116              7.0
# 117              8.0
#
# [10 rows x 28 columns]

# %%
data.shape
# Out:
# (118, 28)

# %%
data.keys()
# Out:
# Index(['AtomicNumber', 'Element', 'Symbol', 'AtomicMass', 'NumberofNeutrons',
#        'NumberofProtons', 'NumberofElectrons', 'Period', 'Group', 'Phase',
#        'Radioactive', 'Natural', 'Metal', 'Nonmetal', 'Metalloid', 'Type',
#        'AtomicRadius', 'Electronegativity', 'FirstIonization', 'Density',
#        'MeltingPoint', 'BoilingPoint', 'NumberOfIsotopes', 'Discoverer',
#        'Year', 'SpecificHeat', 'NumberofShells', 'NumberofValence'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['AtomicNumber', 'Element', 'Symbol', 'AtomicMass', 'NumberofNeutrons',
#        'NumberofProtons', 'NumberofElectrons', 'Period', 'Group', 'Phase',
#        'Radioactive', 'Natural', 'Metal', 'Nonmetal', 'Metalloid', 'Type',
#        'AtomicRadius', 'Electronegativity', 'FirstIonization', 'Density',
#        'MeltingPoint', 'BoilingPoint', 'NumberOfIsotopes', 'Discoverer',
#        'Year', 'SpecificHeat', 'NumberofShells', 'NumberofValence'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=118, step=1)

# %% [markdown]
# Let's make the Element column the index

# %%
data.set_index('Element', inplace=True, drop=False) # inplace=True changes the DataFrame 'data' directly. 
                                                    # USE WITH CAUTION!
data.head(10)
# Out:
#            AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen              1   Hydrogen      H       1.007                 0
# Helium                2     Helium     He       4.002                 2
# Lithium               3    Lithium     Li       6.941                 4
# Beryllium             4  Beryllium     Be       9.012                 5
# Boron                 5      Boron      B      10.811                 6
# Carbon                6     Carbon      C      12.011                 6
# Nitrogen              7   Nitrogen      N      14.007                 7
# Oxygen                8     Oxygen      O      15.999                 8
# Fluorine              9   Fluorine      F      18.998                10
# Neon                 10       Neon     Ne      20.180                10
#
#            NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                              ...
# Hydrogen                 1                  1       1    1.0    gas  ...
# Helium                   2                  2       1   18.0    gas  ...
# Lithium                  3                  3       2    1.0  solid  ...
# Beryllium                4                  4       2    2.0  solid  ...
# Boron                    5                  5       2   13.0  solid  ...
# Carbon                   6                  6       2   14.0  solid  ...
# Nitrogen                 7                  7       2   15.0    gas  ...
# Oxygen                   8                  8       2   16.0    gas  ...
# Fluorine                 9                  9       2   17.0    gas  ...
# Neon                    10                 10       2   18.0    gas  ...
#
#           FirstIonization   Density MeltingPoint BoilingPoint  \
# Element
# Hydrogen          13.5984  0.000090       14.175        20.28
# Helium            24.5874  0.000179          NaN         4.22
# Lithium            5.3917  0.534000      453.850      1615.00
# Beryllium          9.3227  1.850000     1560.150      2742.00
# Boron              8.2980  2.340000     2573.150      4200.00
# Carbon            11.2603  2.270000     3948.150      4300.00
# Nitrogen          14.5341  0.001250       63.290        77.36
# Oxygen            13.6181  0.001430       50.500        90.20
# Fluorine          17.4228  0.001700       53.630        85.03
# Neon              21.5645  0.000900       24.703        27.07
#
#           NumberOfIsotopes          Discoverer    Year  SpecificHeat  \
# Element
# Hydrogen               3.0           Cavendish  1766.0        14.304
# Helium                 5.0             Janssen  1868.0         5.193
# Lithium                5.0           Arfvedson  1817.0         3.582
# Beryllium              6.0          Vaulquelin  1798.0         1.825
# Boron                  6.0          Gay-Lussac  1808.0         1.026
# Carbon                 7.0         Prehistoric     NaN         0.709
# Nitrogen               8.0          Rutherford  1772.0         1.040
# Oxygen                 8.0   Priestley/Scheele  1774.0         0.918
# Fluorine               6.0             Moissan  1886.0         0.824
# Neon                   8.0  Ramsay and Travers  1898.0         1.030
#
#            NumberofShells  NumberofValence
# Element
# Hydrogen                1              1.0
# Helium                  1              NaN
# Lithium                 2              1.0
# Beryllium               2              2.0
# Boron                   2              3.0
# Carbon                  2              4.0
# Nitrogen                2              5.0
# Oxygen                  2              6.0
# Fluorine                2              7.0
# Neon                    2              8.0
#
# [10 rows x 28 columns]

# %%
data.index
# Out:
# Index(['Hydrogen', 'Helium', 'Lithium', 'Beryllium', 'Boron', 'Carbon',
#        'Nitrogen', 'Oxygen', 'Fluorine', 'Neon',
#        ...
#        'Meitnerium', 'Darmstadtium ', 'Roentgenium ', 'Copernicium ',
#        'Nihonium', 'Flerovium', 'Moscovium', 'Livermorium', 'Tennessine',
#        'Oganesson'],
#       dtype='object', name='Element', length=118)

# %%
# slicing by implicit integer index
data[0:5]
# Out:
#            AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen              1   Hydrogen      H       1.007                 0
# Helium                2     Helium     He       4.002                 2
# Lithium               3    Lithium     Li       6.941                 4
# Beryllium             4  Beryllium     Be       9.012                 5
# Boron                 5      Boron      B      10.811                 6
#
#            NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                              ...
# Hydrogen                 1                  1       1    1.0    gas  ...
# Helium                   2                  2       1   18.0    gas  ...
# Lithium                  3                  3       2    1.0  solid  ...
# Beryllium                4                  4       2    2.0  solid  ...
# Boron                    5                  5       2   13.0  solid  ...
#
#           FirstIonization   Density MeltingPoint BoilingPoint  \
# Element
# Hydrogen          13.5984  0.000090       14.175        20.28
# Helium            24.5874  0.000179          NaN         4.22
# Lithium            5.3917  0.534000      453.850      1615.00
# Beryllium          9.3227  1.850000     1560.150      2742.00
# Boron              8.2980  2.340000     2573.150      4200.00
#
#           NumberOfIsotopes  Discoverer    Year  SpecificHeat  NumberofShells  \
# Element
# Hydrogen               3.0   Cavendish  1766.0        14.304               1
# Helium                 5.0     Janssen  1868.0         5.193               1
# Lithium                5.0   Arfvedson  1817.0         3.582               2
# Beryllium              6.0  Vaulquelin  1798.0         1.825               2
# Boron                  6.0  Gay-Lussac  1808.0         1.026               2
#
#            NumberofValence
# Element
# Hydrogen               1.0
# Helium                 NaN
# Lithium                1.0
# Beryllium              2.0
# Boron                  3.0
#
# [5 rows x 28 columns]

# %%
# slicing by explicit index
data['Hydrogen':'Carbon']
# Out:
#            AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen              1   Hydrogen      H       1.007                 0
# Helium                2     Helium     He       4.002                 2
# Lithium               3    Lithium     Li       6.941                 4
# Beryllium             4  Beryllium     Be       9.012                 5
# Boron                 5      Boron      B      10.811                 6
# Carbon                6     Carbon      C      12.011                 6
#
#            NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                              ...
# Hydrogen                 1                  1       1    1.0    gas  ...
# Helium                   2                  2       1   18.0    gas  ...
# Lithium                  3                  3       2    1.0  solid  ...
# Beryllium                4                  4       2    2.0  solid  ...
# Boron                    5                  5       2   13.0  solid  ...
# Carbon                   6                  6       2   14.0  solid  ...
#
#           FirstIonization   Density MeltingPoint BoilingPoint  \
# Element
# Hydrogen          13.5984  0.000090       14.175        20.28
# Helium            24.5874  0.000179          NaN         4.22
# Lithium            5.3917  0.534000      453.850      1615.00
# Beryllium          9.3227  1.850000     1560.150      2742.00
# Boron              8.2980  2.340000     2573.150      4200.00
# Carbon            11.2603  2.270000     3948.150      4300.00
#
#           NumberOfIsotopes   Discoverer    Year  SpecificHeat  NumberofShells  \
# Element
# Hydrogen               3.0    Cavendish  1766.0        14.304               1
# Helium                 5.0      Janssen  1868.0         5.193               1
# Lithium                5.0    Arfvedson  1817.0         3.582               2
# Beryllium              6.0   Vaulquelin  1798.0         1.825               2
# Boron                  6.0   Gay-Lussac  1808.0         1.026               2
# Carbon                 7.0  Prehistoric     NaN         0.709               2
#
#            NumberofValence
# Element
# Hydrogen               1.0
# Helium                 NaN
# Lithium                1.0
# Beryllium              2.0
# Boron                  3.0
# Carbon                 4.0
#
# [6 rows x 28 columns]

# %%
data3 = pd.Series(['a', 'b', 'c'], index = [1, 2, 4])
data3
# Out:
# 1    a
# 2    b
# 4    c
# dtype: object

# %%
# Explict index
data3[1]
# Out:
# 'a'

# %%
# implict index # Py index
data3[1:3]
# Out:
# 2    b
# 4    c
# dtype: object

# %%
data3[0:1]  # implicit index
# Out:
# 1    a
# dtype: object

# %%
data3[1]  # explicit index
# Out:
# 'a'

# %% [markdown]
# #### Exercise 3:  What's the difference between slicing with an explicit index and slicing with an implicit index?

# %% [markdown]
# The following answer is cited from Python Data Science Handbook.
# Slicing with an explicit index (i.e., data['a', 'c']), the final index is included in this operation. While we slice the series with an implicit index (i.e., data[0:2]), the final index is excluded from the slice.

# %% [markdown]
# If the numpy series has an explicit integer index, an indexing operation such as data[1] will use the explicit indices, while a slicing operation like data[1:2] will use the implicit index.

# %% [markdown]
# There are some indexer attributes in Pandas. For example, the loc attribute allows indexing and slicing that always references the explicit index. While using the iloc attribute, we could tell that the attribute allows indexing and slicing that always references the implicit index. # More examples: https://jakevdp.github.io/PythonDataScienceHandbook/03.02-data-indexing-and-selection.html

# %% [markdown]
# #### Indexing

# %%
# access the individual Series that make up the columns of the DataFrame (attibute-style)
data.AtomicMass
# Out:
# Element
# Hydrogen         1.007
# Helium           4.002
# Lithium          6.941
# Beryllium        9.012
# Boron           10.811
#                 ...
# Flerovium      289.000
# Moscovium      288.000
# Livermorium    292.000
# Tennessine     295.000
# Oganesson      294.000
# Name: AtomicMass, Length: 118, dtype: float64

# %%
# Equivalently, via dictionary-style indexing
data['AtomicMass']
# Out:
# Element
# Hydrogen         1.007
# Helium           4.002
# Lithium          6.941
# Beryllium        9.012
# Boron           10.811
#                 ...
# Flerovium      289.000
# Moscovium      288.000
# Livermorium    292.000
# Tennessine     295.000
# Oganesson      294.000
# Name: AtomicMass, Length: 118, dtype: float64

# %%
# access the individual data
data['Symbol'][5]
# note that 5 means the sixth (0, 1, 2, 3, 4, 5)
# Out:
# 'C'

# %%
data.Symbol['Carbon']
# Out:
# 'C'

# %%
data.loc['Carbon', 'Symbol']
# Out:
# 'C'

# %% [markdown]
# You can use the above indexing techniques to replace data values, as shown in the Supplementary Examples 1) section at the end of this Notebook.

# %% [markdown]
# #### Masking

# %% [markdown]
# Although 'masking' is usually associated with the `mask` method https://www.w3schools.com/python/pandas/ref_df_mask.asp, it is also used by some to describe 'data filtering' (i.e. choosing data that fits some criteria):

# %%
# direct masking operations are interpreted row-wise rather than column-wise
data[(data['AtomicMass'] < 10) & (data['Density'] > 0.5)]
# Out:
#            AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Lithium               3    Lithium     Li       6.941                 4
# Beryllium             4  Beryllium     Be       9.012                 5
#
#            NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                              ...
# Lithium                  3                  3       2    1.0  solid  ...
# Beryllium                4                  4       2    2.0  solid  ...
#
#           FirstIonization Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# Element
# Lithium            5.3917   0.534       453.85       1615.0              5.0
# Beryllium          9.3227   1.850      1560.15       2742.0              6.0
#
#            Discoverer    Year  SpecificHeat  NumberofShells  NumberofValence
# Element
# Lithium     Arfvedson  1817.0         3.582               2              1.0
# Beryllium  Vaulquelin  1798.0         1.825               2              2.0
#
# [2 rows x 28 columns]

# %% [markdown]
# #### Exercise 4: Please get data with melting point higher than boiling point.

# %%
data[(data['MeltingPoint'] > data['BoilingPoint'])]
# Out:
#              AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Arsenic                33      Arsenic     As      74.922                42
# Berkelium              97    Berkelium     Bk     247.000               150
# Californium            98  Californium     Cf     251.000               153
#
#              NumberofProtons  NumberofElectrons  Period  Group       Phase  \
# Element
# Arsenic                   33                 33       4   15.0       solid
# Berkelium                 97                 97       7    NaN  artificial
# Californium               98                 98       7    NaN  artificial
#
#              ... FirstIonization Density MeltingPoint BoilingPoint  \
# Element      ...
# Arsenic      ...          9.7886    5.78      1090.15        887.0
# Berkelium    ...          6.1979   14.80      1259.15        983.0
# Californium  ...          6.2817   15.10      1925.15       1173.0
#
#             NumberOfIsotopes       Discoverer    Year  SpecificHeat  \
# Element
# Arsenic                 14.0  Albertus Magnus  1250.0         0.329
# Berkelium               83.0   Seaborg et al.  1949.0           NaN
# Californium            123.0   Seaborg et al.  1950.0           NaN
#
#              NumberofShells  NumberofValence
# Element
# Arsenic                   4              5.0
# Berkelium                 7              NaN
# Californium               7              NaN
#
# [3 rows x 28 columns]

# %% [markdown]
# ### 3. Manipulating data with Pandas

# %%
# create a column with NumberofNeutrons + NumberofProtons
data['Core'] = data['NumberofNeutrons'] + data['NumberofProtons']

# %%
data.head()
# Out:
#            AtomicNumber    Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen              1   Hydrogen      H       1.007                 0
# Helium                2     Helium     He       4.002                 2
# Lithium               3    Lithium     Li       6.941                 4
# Beryllium             4  Beryllium     Be       9.012                 5
# Boron                 5      Boron      B      10.811                 6
#
#            NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                              ...
# Hydrogen                 1                  1       1    1.0    gas  ...
# Helium                   2                  2       1   18.0    gas  ...
# Lithium                  3                  3       2    1.0  solid  ...
# Beryllium                4                  4       2    2.0  solid  ...
# Boron                    5                  5       2   13.0  solid  ...
#
#             Density MeltingPoint BoilingPoint NumberOfIsotopes  Discoverer  \
# Element
# Hydrogen   0.000090       14.175        20.28              3.0   Cavendish
# Helium     0.000179          NaN         4.22              5.0     Janssen
# Lithium    0.534000      453.850      1615.00              5.0   Arfvedson
# Beryllium  1.850000     1560.150      2742.00              6.0  Vaulquelin
# Boron      2.340000     2573.150      4200.00              6.0  Gay-Lussac
#
#              Year  SpecificHeat  NumberofShells  NumberofValence  Core
# Element
# Hydrogen   1766.0        14.304               1              1.0     1
# Helium     1868.0         5.193               1              NaN     4
# Lithium    1817.0         3.582               2              1.0     7
# Beryllium  1798.0         1.825               2              2.0     9
# Boron      1808.0         1.026               2              3.0    11
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Handling missing data:

# %% [markdown]
# ``None``: Pythonic missing data, which cannot be used in any arbitrary NumPy/Pandas array, but only in arrays with data type 'object' (i.e., arrays of Python objects).

# %% [markdown]
# ``NaN``: Missing numerical data (acronym for *Not a Number*), a special floating-point value.

# %%
example1 = np.array([0, 1, 2, 3])
example2 = np.array([0, 1, None, 3])
print(example1.dtype, example2.dtype)
# Out:
# int64 object

# %%
example1 + 5
# Out:
# array([5, 6, 7, 8])

# %%
example2 + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_206/3851745732.py in <module>
# ----> 1 example2 + 5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
np.nan * 2
# Out:
# nan

# %% [markdown]
# Pandas is built to handle ``NaN`` and ``None`` nearly interchangeable.

# %% [markdown]
# We can use ``isna()`` to generate a boolean mask indicating missing values.

# %%
data.isna()
# Out:
#              AtomicNumber  Element  Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen            False    False   False       False             False
# Helium              False    False   False       False             False
# Lithium             False    False   False       False             False
# Beryllium           False    False   False       False             False
# Boron               False    False   False       False             False
# ...                   ...      ...     ...         ...               ...
# Flerovium           False    False   False       False             False
# Moscovium           False    False   False       False             False
# Livermorium         False    False   False       False             False
# Tennessine          False    False   False       False             False
# Oganesson           False    False   False       False             False
#
#              NumberofProtons  NumberofElectrons  Period  Group  Phase  ...  \
# Element                                                                ...
# Hydrogen               False              False   False  False  False  ...
# Helium                 False              False   False  False  False  ...
# Lithium                False              False   False  False  False  ...
# Beryllium              False              False   False  False  False  ...
# Boron                  False              False   False  False  False  ...
# ...                      ...                ...     ...    ...    ...  ...
# Flerovium              False              False   False  False  False  ...
# Moscovium              False              False   False  False  False  ...
# Livermorium            False              False   False  False  False  ...
# Tennessine             False              False   False  False  False  ...
# Oganesson              False              False   False  False  False  ...
#
#              Density  MeltingPoint  BoilingPoint  NumberOfIsotopes  \
# Element
# Hydrogen       False         False         False             False
# Helium         False          True         False             False
# Lithium        False         False         False             False
# Beryllium      False         False         False             False
# Boron          False         False         False             False
# ...              ...           ...           ...               ...
# Flerovium       True          True          True              True
# Moscovium       True          True          True              True
# Livermorium     True          True          True              True
# Tennessine      True          True          True              True
# Oganesson       True          True          True              True
#
#              Discoverer   Year  SpecificHeat  NumberofShells  NumberofValence  \
# Element
# Hydrogen          False  False         False           False            False
# Helium            False  False         False           False             True
# Lithium           False  False         False           False            False
# Beryllium         False  False         False           False            False
# Boron             False  False         False           False            False
# ...                 ...    ...           ...             ...              ...
# Flerovium          True  False          True           False            False
# Moscovium          True  False          True           False            False
# Livermorium        True  False          True           False            False
# Tennessine         True  False          True           False            False
# Oganesson          True  False          True           False            False
#
#               Core
# Element
# Hydrogen     False
# Helium       False
# Lithium      False
# Beryllium    False
# Boron        False
# ...            ...
# Flerovium    False
# Moscovium    False
# Livermorium  False
# Tennessine   False
# Oganesson    False
#
# [118 rows x 29 columns]

# %% [markdown]
# We can drop NA values using ``dropna()`` method. By default, ``dropna()`` will drop all rows in which any null value is present.

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [AtomicNumber, Element, Symbol, AtomicMass, NumberofNeutrons, NumberofProtons, NumberofElectrons, Period, Group, Phase, Radioactive, Natural, Metal, Nonmetal, Metalloid, Type, AtomicRadius, Electronegativity, FirstIonization, Density, MeltingPoint, BoilingPoint, NumberOfIsotopes, Discoverer, Year, SpecificHeat, NumberofShells, NumberofValence, Core]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# Alternatively, we can drop NA values along a different axis; axis=1 drops all columns containing a null value. Dropping rows or columns with all NA values or a majority of NA values can be specified through the ``how`` or ``thresh`` parameters. Hint: Google is your friend!

# %%
data.dropna(how='all') # how='any' is another option. See https://www.w3resource.com/pandas/dataframe/dataframe-dropna.php
# Out:
#              AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# Element
# Hydrogen                1     Hydrogen      H       1.007                 0
# Helium                  2       Helium     He       4.002                 2
# Lithium                 3      Lithium     Li       6.941                 4
# Beryllium               4    Beryllium     Be       9.012                 5
# Boron                   5        Boron      B      10.811                 6
# ...                   ...          ...    ...         ...               ...
# Flerovium             114    Flerovium     Fl     289.000               175
# Moscovium             115    Moscovium     Mc     288.000               173
# Livermorium           116  Livermorium     Lv     292.000               176
# Tennessine            117   Tennessine     Ts     295.000               178
# Oganesson             118    Oganesson     Og     294.000               176
#
#              NumberofProtons  NumberofElectrons  Period  Group       Phase  \
# Element
# Hydrogen                   1                  1       1    1.0         gas
# Helium                     2                  2       1   18.0         gas
# Lithium                    3                  3       2    1.0       solid
# Beryllium                  4                  4       2    2.0       solid
# Boron                      5                  5       2   13.0       solid
# ...                      ...                ...     ...    ...         ...
# Flerovium                114                114       7   14.0  artificial
# Moscovium                115                115       7   15.0  artificial
# Livermorium              116                116       7   16.0  artificial
# Tennessine               117                117       7   17.0  artificial
# Oganesson                118                118       7   18.0  artificial
#
#              ...   Density MeltingPoint BoilingPoint NumberOfIsotopes  \
# Element      ...
# Hydrogen     ...  0.000090       14.175        20.28              3.0
# Helium       ...  0.000179          NaN         4.22              5.0
# Lithium      ...  0.534000      453.850      1615.00              5.0
# Beryllium    ...  1.850000     1560.150      2742.00              6.0
# Boron        ...  2.340000     2573.150      4200.00              6.0
# ...          ...       ...          ...          ...              ...
# Flerovium    ...       NaN          NaN          NaN              NaN
# Moscovium    ...       NaN          NaN          NaN              NaN
# Livermorium  ...       NaN          NaN          NaN              NaN
# Tennessine   ...       NaN          NaN          NaN              NaN
# Oganesson    ...       NaN          NaN          NaN              NaN
#
#              Discoverer    Year  SpecificHeat  NumberofShells  \
# Element
# Hydrogen      Cavendish  1766.0        14.304               1
# Helium          Janssen  1868.0         5.193               1
# Lithium       Arfvedson  1817.0         3.582               2
# Beryllium    Vaulquelin  1798.0         1.825               2
# Boron        Gay-Lussac  1808.0         1.026               2
# ...                 ...     ...           ...             ...
# Flerovium           NaN  1999.0           NaN               7
# Moscovium           NaN  2010.0           NaN               7
# Livermorium         NaN  2000.0           NaN               7
# Tennessine          NaN  2010.0           NaN               7
# Oganesson           NaN  2006.0           NaN               7
#
#              NumberofValence  Core
# Element
# Hydrogen                 1.0     1
# Helium                   NaN     4
# Lithium                  1.0     7
# Beryllium                2.0     9
# Boron                    3.0    11
# ...                      ...   ...
# Flerovium                4.0   289
# Moscovium                5.0   288
# Livermorium              6.0   292
# Tennessine               7.0   295
# Oganesson                8.0   294
#
# [118 rows x 29 columns]

# %% [markdown]
# If the above behavior is unexpected, it could be that the following fact went unnoticed: Each row has at least one NA entry. To see this, simply run ``pd.set_option('display.max_columns', None)`` in a new cell, and visualize the DataFrame again by running ``data``. You may also look at Supplemental Examples 2) at the end of this Notebook.

# %% [markdown]
# #### Exercise 5: Drop rows with more than 2 NA values. Hint: use ``thresh``. See Supplementary Examples 2) if you need more hints).

# %%
data.dropna(thresh = 27)  # 'thresh = 27' means there should be 27 non-Nan values in a row
                          # In the example, rows with more than 2 NA values (thresh < 27) will be dropped.
# Out:
# Empty DataFrame
# Columns: [AtomicNumber, Element, Symbol, AtomicMass, NumberofNeutrons, NumberofProtons, NumberofElectrons, Period, Group, Phase, Radioactive, Natural, Metal, Nonmetal, Metalloid, Type, AtomicRadius, Electronegativity, FirstIonization, Density, MeltingPoint, BoilingPoint, NumberOfIsotopes, Discoverer, Year, SpecificHeat, NumberofShells, NumberofValence, Core]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ### Combining datasets
# The ``append()`` method in Pandas does not modify the original object – instead it creates a new object with the combined data.

# %%
d = [{'A': i, 'B': 2 * i}
     for i in range(3)]
df1 = pd.DataFrame(d)
df1
# Out:
#    A  B
# 0  0  0
# 1  1  2
# 2  2  4

# %%
d = [{'A': i, 'B': -i}
     for i in range(3)]
df2 = pd.DataFrame(d)
df2
# Out:
#    A  B
# 0  0  0
# 1  1 -1
# 2  2 -2

# %%
df1.append(df2)
# Out:
#    A  B
# 0  0  0
# 1  1  2
# 2  2  4
# 0  0  0
# 1  1 -1
# 2  2 -2

# %%
d = [{'a': i, 'b': -i}
     for i in range(3)]
df3 = pd.DataFrame(d)
df3
# Out:
#    a  b
# 0  0  0
# 1  1 -1
# 2  2 -2

# %%
df1.append(df3)
# Out:
#      A    B    a    b
# 0  0.0  0.0  NaN  NaN
# 1  1.0  2.0  NaN  NaN
# 2  2.0  4.0  NaN  NaN
# 0  NaN  NaN  0.0  0.0
# 1  NaN  NaN  1.0 -1.0
# 2  NaN  NaN  2.0 -2.0

# %%
df1.append(df3,ignore_index=True)
# Out:
#      A    B    a    b
# 0  0.0  0.0  NaN  NaN
# 1  1.0  2.0  NaN  NaN
# 2  2.0  4.0  NaN  NaN
# 3  NaN  NaN  0.0  0.0
# 4  NaN  NaN  1.0 -1.0
# 5  NaN  NaN  2.0 -2.0

# %% [markdown]
# We should pay attention to how it works.

# %% [markdown]
# ### 4. Aggregation and Grouping

# %% [markdown]
# ### Simple Aggregation in Pandas

# %%
data['NumberofElectrons'].sum()
# Out:
# 7021

# %%
data.dropna(how='all').describe()
# Out:
#        AtomicNumber  AtomicMass  NumberofNeutrons  NumberofProtons  \
# count    118.000000  118.000000        118.000000       118.000000
# mean      59.500000  145.988297         86.483051        59.500000
# std       34.207699   88.954899         54.785320        34.207699
# min        1.000000    1.007000          0.000000         1.000000
# 25%       30.250000   66.465750         36.000000        30.250000
# 50%       59.500000  142.575000         83.000000        59.500000
# 75%       88.750000  226.750000        138.000000        88.750000
# max      118.000000  295.000000        178.000000       118.000000
#
#        NumberofElectrons      Period      Group  AtomicRadius  \
# count         118.000000  118.000000  90.000000     86.000000
# mean           59.500000    5.254237   9.944444      1.825814
# std            34.207699    1.618200   5.597674      0.611058
# min             1.000000    1.000000   1.000000      0.490000
# 25%            30.250000    4.000000   5.000000      1.425000
# 50%            59.500000    6.000000  10.500000      1.800000
# 75%            88.750000    7.000000  15.000000      2.200000
# max           118.000000    7.000000  18.000000      3.300000
#
#        Electronegativity  FirstIonization     Density  MeltingPoint  \
# count          96.000000       102.000000  105.000000     98.000000
# mean            1.695000         7.988505    9.232161   1281.475184
# std             0.621174         3.334571    8.630406    903.685175
# min             0.700000         3.893900    0.000090     14.175000
# 25%             1.237500         6.004850    2.700000    510.695000
# 50%             1.585000         6.960250    7.290000   1204.150000
# 75%             2.062500         8.964925   12.000000   1811.150000
# max             3.980000        24.587400   41.000000   3948.150000
#
#        BoilingPoint  NumberOfIsotopes         Year  SpecificHeat  \
# count     98.000000        103.000000   107.000000     85.000000
# mean    2513.143163         28.116505  1865.280374      0.635976
# std     1601.901036         35.864205    97.951740      1.653965
# min        4.220000          3.000000  1250.000000      0.094000
# 25%     1069.000000         11.000000  1803.500000      0.168000
# 50%     2767.000000         19.000000  1878.000000      0.244000
# 75%     3596.750000         24.000000  1940.000000      0.489000
# max     5869.000000        203.000000  2010.000000     14.304000
#
#        NumberofShells  NumberofValence        Core
# count      118.000000        49.000000  118.000000
# mean         5.254237         4.428571  145.983051
# std          1.618200         2.345208   88.945386
# min          1.000000         1.000000    1.000000
# 25%          4.000000         2.000000   66.250000
# 50%          6.000000         4.000000  142.500000
# 75%          7.000000         6.000000  226.750000
# max          7.000000         8.000000  295.000000

# %% [markdown]
# ### GroupBy: Spilt, Apply, Combine
#
# The real power of Pandas comes in its tools for grouping and aggregating data. Here we'll look at the basics of *GroupBy* operations (image adopted from [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html))
# ![image](https://jakevdp.github.io/PythonDataScienceHandbook/figures/03.08-split-apply-combine.png)

# %%
data.groupby(['Group']).count()
# Out:
#        AtomicNumber  Element  Symbol  AtomicMass  NumberofNeutrons  \
# Group
# 1.0               7        7       7           7                 7
# 2.0               6        6       6           6                 6
# 3.0               4        4       4           4                 4
# 4.0               4        4       4           4                 4
# 5.0               4        4       4           4                 4
# 6.0               4        4       4           4                 4
# 7.0               4        4       4           4                 4
# 8.0               4        4       4           4                 4
# 9.0               4        4       4           4                 4
# 10.0              4        4       4           4                 4
# 11.0              4        4       4           4                 4
# 12.0              4        4       4           4                 4
# 13.0              6        6       6           6                 6
# 14.0              6        6       6           6                 6
# 15.0              6        6       6           6                 6
# 16.0              6        6       6           6                 6
# 17.0              6        6       6           6                 6
# 18.0              7        7       7           7                 7
#
#        NumberofProtons  NumberofElectrons  Period  Phase  Radioactive  ...  \
# Group                                                                  ...
# 1.0                  7                  7       7      7            1  ...
# 2.0                  6                  6       6      6            1  ...
# 3.0                  4                  4       4      4            1  ...
# 4.0                  4                  4       4      4            1  ...
# 5.0                  4                  4       4      4            1  ...
# 6.0                  4                  4       4      4            1  ...
# 7.0                  4                  4       4      4            2  ...
# 8.0                  4                  4       4      4            1  ...
# 9.0                  4                  4       4      4            1  ...
# 10.0                 4                  4       4      4            1  ...
# 11.0                 4                  4       4      4            1  ...
# 12.0                 4                  4       4      4            1  ...
# 13.0                 6                  6       6      6            1  ...
# 14.0                 6                  6       6      6            1  ...
# 15.0                 6                  6       6      6            1  ...
# 16.0                 6                  6       6      6            2  ...
# 17.0                 6                  6       6      6            2  ...
# 18.0                 7                  7       7      7            2  ...
#
#        Density  MeltingPoint  BoilingPoint  NumberOfIsotopes  Discoverer  \
# Group
# 1.0          7             7             7                 7           7
# 2.0          6             6             6                 6           6
# 3.0          4             4             4                 4           4
# 4.0          4             3             3                 3           4
# 5.0          4             3             3                 3           4
# 6.0          4             3             3                 3           4
# 7.0          4             3             3                 3           4
# 8.0          4             3             3                 3           4
# 9.0          4             3             3                 3           4
# 10.0         3             3             3                 3           3
# 11.0         3             3             3                 3           3
# 12.0         3             3             3                 3           3
# 13.0         5             5             5                 5           5
# 14.0         5             5             5                 5           5
# 15.0         5             5             5                 5           5
# 16.0         5             5             5                 5           5
# 17.0         5             5             5                 5           5
# 18.0         6             5             6                 6           6
#
#        Year  SpecificHeat  NumberofShells  NumberofValence  Core
# Group
# 1.0       7             6               7                7     7
# 2.0       6             5               6                6     6
# 3.0       4             4               4                0     4
# 4.0       4             3               4                0     4
# 5.0       4             3               4                0     4
# 6.0       4             3               4                0     4
# 7.0       4             2               4                0     4
# 8.0       3             3               4                0     4
# 9.0       4             3               4                0     4
# 10.0      4             3               4                0     4
# 11.0      1             3               4                0     4
# 12.0      2             3               4                0     4
# 13.0      6             5               6                6     6
# 14.0      3             5               6                6     6
# 15.0      5             5               6                6     6
# 16.0      5             4               6                6     6
# 17.0      6             4               6                6     6
# 18.0      7             6               7                6     7
#
# [18 rows x 28 columns]

# %% [markdown]
# #### Exercise 6:  How to group data by Period?

# %%
data.groupby(['Period']).count()
# Out:
#         AtomicNumber  Element  Symbol  AtomicMass  NumberofNeutrons  \
# Period
# 1                  2        2       2           2                 2
# 2                  8        8       8           8                 8
# 3                  8        8       8           8                 8
# 4                 18       18      18          18                18
# 5                 18       18      18          18                18
# 6                 32       32      32          32                32
# 7                 32       32      32          32                32
#
#         NumberofProtons  NumberofElectrons  Group  Phase  Radioactive  ...  \
# Period                                                                 ...
# 1                     2                  2      2      2            0  ...
# 2                     8                  8      8      8            0  ...
# 3                     8                  8      8      8            0  ...
# 4                    18                 18     18     18            0  ...
# 5                    18                 18     18     18            1  ...
# 6                    32                 32     18     32            4  ...
# 7                    32                 32     18     32           32  ...
#
#         Density  MeltingPoint  BoilingPoint  NumberOfIsotopes  Discoverer  \
# Period
# 1             2             1             2                 2           2
# 2             8             8             8                 8           8
# 3             8             8             8                 8           8
# 4            18            18            18                18          18
# 5            18            18            18                18          18
# 6            32            32            32                32          32
# 7            19            13            12                17          23
#
#         Year  SpecificHeat  NumberofShells  NumberofValence  Core
# Period
# 1          2             2               2                1     2
# 2          7             8               8                8     8
# 3          7             8               8                8     8
# 4         15            18              18                8    18
# 5         15            17              18                8    18
# 6         29            29              32                8    32
# 7         32             3              32                8    32
#
# [7 rows x 28 columns]

# %% [markdown]
# #### Exercise 7:  Calculate the average Atomic Mass of data grouped by Period.

# %%
data.groupby(['Period'])['AtomicMass'].mean()
# Out:
# Period
# 1      2.504500
# 2     13.494875
# 3     30.100375
# 4     60.678833
# 5    106.213556
# 6    174.271312
# 7    259.128219
# Name: AtomicMass, dtype: float64

# %% [markdown]
# We can specify a groupby using the names of table columns and compute other functions, such as the ``sum``, ``count``, ``mean``, and ``describe``.

# %%
data.groupby(['Group'])['Density'].describe()
# Out:
#        count       mean        std       min       25%        50%       75%  \
# Group
# 1.0      7.0   1.091013   0.703986  0.000090   0.69800   0.971000   1.70000
# 2.0      6.0   2.810000   1.520053  1.540000   1.76750   2.245000   3.35250
# 3.0      4.0   5.927500   3.066620  2.990000   4.10000   5.310000   7.13750
# 4.0      4.0  10.612500   6.244760  4.540000   6.01750   9.905000  14.50000
# 5.0      4.0  17.595000  14.970314  6.110000   7.95500  12.635000  22.27500
# 6.0      4.0  17.912500  12.506290  7.150000   9.43750  14.750000  23.22500
# 7.0      4.0  19.235000  13.135990  7.440000  10.48500  16.250000  25.00000
# 8.0      4.0  20.967500  14.707285  7.870000  11.26750  17.500000  27.20000
# 9.0      4.0  19.715000  11.737329  8.860000  11.51500  17.500000  25.70000
# 10.0     3.0  14.136667   6.561329  8.910000  10.45500  12.000000  16.75000
# 11.0     3.0  12.920000   5.578638  8.960000   9.73000  10.500000  14.90000
# 12.0     3.0   9.773333   3.320306  7.130000   7.91000   8.690000  11.09500
# 13.0     5.0   6.032000   3.899188  2.340000   2.70000   5.910000   7.31000
# 14.0     5.0   5.702000   3.780022  2.270000   2.33000   5.320000   7.29000
# 15.0     5.0   4.820250   3.922338  0.001250   1.82000   5.780000   6.69000
# 16.0     5.0   4.486286   3.621550  0.001430   2.07000   4.810000   6.23000
# 17.0     5.0   3.010982   3.070393  0.001700   0.00321   3.120000   4.93000
# 18.0     6.0   0.003701   0.003608  0.000179   0.00112   0.002755   0.00535
#
#             max
# Group
# 1.0     1.87000
# 2.0     5.50000
# 3.0    10.10000
# 4.0    18.10000
# 5.0    39.00000
# 6.0    35.00000
# 7.0    37.00000
# 8.0    41.00000
# 9.0    35.00000
# 10.0   21.50000
# 11.0   19.30000
# 12.0   13.50000
# 13.0   11.90000
# 14.0   11.30000
# 15.0    9.81000
# 16.0    9.32000
# 17.0    7.00000
# 18.0    0.00973

# %% [markdown]
# # Supplementary Examples (use as-needed)

# %% [markdown]
# Let's use a simpler/smaller DataFrame in these supplementary examples.

# %%
df = pd.DataFrame({"name": ['Superman', 'Batman', 'Spiderman', 'Jibbleman', np.nan],
                   "toy": [np.nan, 'Batmobile', 'Air', 'Jiggle stick', np.nan],
                   "born": [pd.NaT, pd.Timestamp("1956-06-26"), pd.NaT, 2019, np.nan],
                   "eating?": ['yes', 'no', 'maybe', 'eh', np.nan]
                  })
df
# Out:
#         name           toy                 born eating?
# 0   Superman           NaN                  NaT     yes
# 1     Batman     Batmobile  1956-06-26 00:00:00      no
# 2  Spiderman           Air                  NaT   maybe
# 3  Jibbleman  Jiggle stick                 2019      eh
# 4        NaN           NaN                  NaN     NaN

# %% [markdown]
# ## 1) Indexing: Changing Data Values

# %%
df2 = df # always a good idea to backup, as values WILL be overwritten

# The following approaches are equivalent; they just use different indexing styles (as intruduced earlier in the notebook)
df2['name'][1]='Batman TM'  # explicit index
df2.toy[3]='Jiggle sticks'
df2.at[0,'eating']='sometimes' # .at is another way that was not covered earlier in the notebook. 
                               # Each approach has its pros/cons, and some are inherently less ambiguous than others. Please do some research on this!

df2
# Out:
#         name            toy                 born eating?     eating
# 0   Superman            NaN                  NaT     yes  sometimes
# 1  Batman TM      Batmobile  1956-06-26 00:00:00      no        NaN
# 2  Spiderman            Air                  NaT   maybe        NaN
# 3  Jibbleman  Jiggle sticks                 2019      eh        NaN
# 4        NaN            NaN                  NaN     NaN        NaN

# %% [markdown]
# ## 2) More ``isna()`` and ``dropna()``

# %%
df2.isna()
# Out:
#     name    toy   born  eating?  eating
# 0  False   True   True    False   False
# 1  False  False  False    False    True
# 2  False  False   True    False    True
# 3  False  False  False    False    True
# 4   True   True   True     True    True

# %%
df2.dropna(how="any") # delete rows that have at least one NA value. 
                     # Note that if inplace=True is NOT set, 'df' itself is not changed, 
                     # unlike with direct element replacement in Supplementary Examples 1).
# Out:
# Empty DataFrame
# Columns: [name, toy, born, eating?, eating]
# Index: []

# %%
df2.dropna(how="all") # delete rows with NA values in all columns
# Out:
#         name            toy                 born eating?     eating
# 0   Superman            NaN                  NaT     yes  sometimes
# 1  Batman TM      Batmobile  1956-06-26 00:00:00      no        NaN
# 2  Spiderman            Air                  NaT   maybe        NaN
# 3  Jibbleman  Jiggle sticks                 2019      eh        NaN

# %%
df2.dropna(thresh=2) # delete rows with at least 2 non-NA values
# Out:
#         name            toy                 born eating?     eating
# 0   Superman            NaN                  NaT     yes  sometimes
# 1  Batman TM      Batmobile  1956-06-26 00:00:00      no        NaN
# 2  Spiderman            Air                  NaT   maybe        NaN
# 3  Jibbleman  Jiggle sticks                 2019      eh        NaN

# %%
df2.dropna(thresh=4) # delete rows with at least 4 non-NA values
# Out:
#         name            toy                 born eating? eating
# 1  Batman TM      Batmobile  1956-06-26 00:00:00      no    NaN
# 3  Jibbleman  Jiggle sticks                 2019      eh    NaN

# %% [markdown]
# **Optional Exercise:** Overwrite all NA values from a few rows in the DataFrame for the periodic table with any non-NA values, and see how ``dropna()`` yields different results for different ``how`` options!
